# %%
import pandas as pd
import mysql.connector
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt
# Connect to MySQL (update your credentials and database name)
conn = mysql.connector.connect(
    host='127.0.0.1',         
    user='root',
    password='weichi021021',
    database='yelp'  
)
# Define the SQL query to get the average review stars for Beauty & Spas businesses
query = """
SELECT r.text
FROM yelp_review r
JOIN yelp_business b ON r.business_id = b.business_id
WHERE b.categories LIKE '%Beauty & Spas%'
  AND (b.categories LIKE '%Nail%' OR b.name LIKE '%Nail%')
  AND YEAR(r.date) = (
    SELECT MAX(YEAR(date))
    FROM yelp_review
);
"""
df = pd.read_sql(query, conn)
df.to_csv('/Users/weichi/Desktop/beauty_spas_monthly_reviews5.csv', index=False)

conn.close()

# %%
import csv
import numpy as np
months = []
reviews = []

with open('/Users/weichi/Desktop/beauty_spas_monthly_reviews.csv', newline='') as f:
    reader = csv.reader(f)
    next(reader)  # Skip header
    for row in reader:
        months.append(row[0])
        reviews.append(float(row[1]))  # convert to float if you want numerical data
        months.append(row[0])
        reviews.append(float(row[1]))  # convert to float if you want numerical data
months = list(reversed(months))
reviews = list(reversed(reviews))

# %%
months_dt = [dt.datetime.strptime(m, '%Y-%m') for m in months]

plt.figure(figsize=(10, 6))
plt.plot(months_dt, reviews, color='b', label='Average Review')
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=10))
months_numeric = mdates.date2num(months_dt)
x_line = np.linspace(months_numeric.min(), months_numeric.max(), 100)
y_line = 0 * x_line + 4.00

# Plot the dividing line
plt.plot(mdates.num2date(x_line), y_line, color='black', linestyle='--', linewidth=2, label='Average Line')
plt.gcf().autofmt_xdate()  
plt.legend()
plt.show()

# %%
months = []
funny_reviews = []

with open('/Users/weichi/Desktop/beauty_spas_monthly_reviews2.csv', newline='') as f:
    reader = csv.reader(f)
    next(reader)  # Skip header
    for row in reader:
        months.append(row[0])
        funny_reviews.append(float(row[1]))  # convert to float if you want numerical data
        months.append(row[0])
        funny_reviews.append(float(row[1]))  # convert to float if you want numerical data
months = list(reversed(months))
funny_reviews = list(reversed(funny_reviews))

# %%
months_dt = [dt.datetime.strptime(m, '%Y-%m') for m in months]

plt.figure(figsize=(10, 6))
plt.bar(months_dt, funny_reviews, color='b', label='Funny Review', width=25)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=12))
plt.gcf().autofmt_xdate()  
plt.legend()
plt.show()

# %%
months = []
reviews = []

with open('/Users/weichi/Desktop/beauty_spas_monthly_reviews3.csv', newline='') as f:
    reader = csv.reader(f)
    next(reader)  # Skip header
    for row in reader:
        months.append(row[0])
        reviews.append(float(row[1]))  # convert to float if you want numerical data
        months.append(row[0])
        reviews.append(float(row[1]))  # convert to float if you want numerical data
months = list(reversed(months))
reviews = list(reversed(reviews))
months_dt = [dt.datetime.strptime(m, '%Y-%m') for m in months]

plt.figure(figsize=(10, 6))
plt.bar(months_dt, reviews, color='b', label='cool Review', width=25)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=12))
plt.gcf().autofmt_xdate()  
plt.legend()
plt.show()

# %%
months = []
reviews = []

with open('/Users/weichi/Desktop/beauty_spas_monthly_reviews4.csv', newline='') as f:
    reader = csv.reader(f)
    next(reader)  # Skip header
    for row in reader:
        months.append(row[0])
        reviews.append(float(row[1]))  # convert to float if you want numerical data
        months.append(row[0])
        reviews.append(float(row[1]))  # convert to float if you want numerical data
months = list(reversed(months))
reviews = list(reversed(reviews))
months_dt = [dt.datetime.strptime(m, '%Y-%m') for m in months]

plt.figure(figsize=(10, 6))
plt.bar(months_dt, reviews, color='b', label='Useful Review', width=25)
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=12))
plt.gcf().autofmt_xdate()  
plt.legend()
plt.show()

# %%
import nltk
import re
from collections import Counter
reviews = []
with open('/Users/weichi/Desktop/beauty_spas_monthly_reviews5.csv', newline='') as f:
    reader = csv.reader(f)
    next(reader) 
    for row in reader:
        reviews.append(row[0])

# %%
import string
#defining the function to remove punctuation
def remove_punctuation(reviews):
    punctuationfree="".join([i for i in reviews if i not in string.punctuation])
    return punctuationfree
#storing the puntuation free text
reviews_punctuationfree=[]
for i in reviews:
    reviews_punctuationfree.append(remove_punctuation(i))
reviews_punctuationfree[:10]
lower = []
for i in reviews_punctuationfree:
    lower.append(i.lower())
lower[:10]
# Out:
# ['alice jane and the entire staff here stand out above the rest of the nail salons in town  believe me ive tried a vast majority of them \nive now been going here for well over a year  i refer anyone and everyone i know here as well as bringing friends who are in town here  my mom and myself are regulars and we wouldnt have it any other way  \nalways a lovely experience a relaxed ambiance and movies  yes new and current movies as well as some classics \nabsolutely everything about stars nails is comfortable the mani stations the pedi chairs and yes all are facing the tv set for perfect movie viewing  \nclassic mani and pediatric they have them  trendy pedi treatments and facials have them as well  colors of the trendy shades abound \nrejoice  its here for you along with reasonable pricing and excellent service \ndont be ashamed how bad joss feet become boot season is here and those crest feet in wed of a wonderful pedi treatment  star nails has a pedi menu peruse it and be inclined to try all  beauty intervention here is a pleasure tuning those feet and legs  trust me feet deserve this place they do support the entire body think about it why would anyone in their right mind not treat them well \njane alice or any of the staff here will sooth moisturize with a dose of sloughing lotion and buff to perfection ahh what a relief right\nthe finale will be a slight massage for those hands or feet and then polish viola',
#  'thanks to global warming we have been having 70 degree days regularly i was in need of a pedi and happened to be in plaza midwood nikki w gave me two recommendations in the hood and malibu was closest wow what a fantastic experience i was greeted when i walked in and asked what service i needed i just wanted a basic pedi 25 khai took great care of me she was very through and very detail oriented the interior is simple but clean my toes look great and i didnt break the bank ill be back for sure',
#  'the nail tech i had was great and its actually best gel ive had i wouldve given another star if it wasnt for their false check in ad of 10 \n\nto redeem the 10 off for check in the require you to do a review before they honor the 10 whos going to do a proper review while standing at the counter',
#  'my boyfriend made me an appointment on my birthday for us to get pedicures i was so excited to relax i get pedicures every 2 weeks but we recently moved and i was looking for a new place anyway after reading the reviews i was even more excited when i arrived they were very busy my boyfriend was running late and i told them that i even offered for them to take some of the people who walked in and we could wait because it was my birthday and i had all day my boyfriend arrived within the next 5 minutes and we were both rushed through our pedicure we were not offered different options even though i could clearly see a menu in their bucket to pick from i thought maybe they just didnt yes their menu but then i saw them offer it to a lady right next to me i enjoy getting sugar scrub mask and paraffin wax so i was very disappointed to not receive even a choice to add those on needless to say i was not happy with my service and my birthday relaxation i will not be coming back',
#  'be careful here  theyll give you a price list for a pedicure and then add on items that they dont tell you how much they are and your pedicure will end up being more than double at check out my two friends got a deluxe pedicure for 35  they each wanted gel which is usually 10 more at other locations and rockstar sparkle they expected like 45 at checkout mind you no one ever told them how much these addons were when they went to check out their pedicure was 60 jerks never going back',
#  'great salon with really friendly staff kate was my colorist and did an amazing job on my hair i highly recommend this salon and especially kate',
#  'ill start by saying that everyone i have dealt with here is nice ive gone twice for a mens haircut the only comparison i can make is to say that this is like a fancy supercuts ive found both of the stylists that cut my hair to be very timid i tried a second time because i thought i just had a bad first experience i wont be going back a 3rd time',
#  'under new ownership remodel is nice made an apt to get manicure  pedicure a male did my nails despite my apt i had to wait 10 mins did a terrible job filed my nails uneven did a poor job removing my cuticles and also didnt come close to polishing my nails close to top edge of my nails also his nails were dirty and unmanicured it seems like since he works in a nail salon and does manicureshed put in an effort to keep his nails at least clean if not manicured overall bad experience i wont be back',
#  'i love this place i have waited several months to post my review and this place has been consistently amazing christie single handedly guided me on the path to resurrecting my eyebrows from short and thin to a beautiful work in progressi have had eyebrow threading by kelly as well fabulous too other than eyebrow threading and lip threading i had the faux lashes put on they looked beautiful and i received a million compliments \n\n\ni have nothing but wonderful things to say about pbb other reviews indicating a lack of customer service seem off base to me every single person i have ever had contact with at pbb has been kind warm and welcoming i will be a forever customer and will continue commuting into the city just to get my brows done',
#  'mrs ann is wonderful i have been going to health for about two years now and she has never messed up my nails ever she really puts her heart into what she does most of all its affordable thanks mrs ann']

# %%
#defining function for tokenization
import re

def tokenization(text):
    tokens = re.split(r'\W+', text)
    return tokens
#applying function to the column
tokenized_reviews = []
for i in lower:
    tokenized_reviews.append(tokenization(i))
tokenized_reviews[:10]
# Out:
# [['super',
#   'simple',
#   'place',
#   'but',
#   'amazing',
#   'nonetheless',
#   'its',
#   'been',
#   'around',
#   'since',
#   'the',
#   '30s',
#   'and',
#   'they',
#   'still',
#   'serve',
#   'the',
#   'same',
#   'thing',
#   'they',
#   'started',
#   'with',
#   'a',
#   'bologna',
#   'and',
#   'salami',
#   'sandwich',
#   'with',
#   'mustard',
#   'staff',
#   'was',
#   'very',
#   'helpful',
#   'and',
#   'friendly'],
#  ['small',
#   'unassuming',
#   'place',
#   'that',
#   'changes',
#   'their',
#   'menu',
#   'every',
#   'so',
#   'often',
#   'cool',
#   'decor',
#   'and',
#   'vibe',
#   'inside',
#   'their',
#   '30',
#   'seat',
#   'restaurant',
#   'call',
#   'for',
#   'a',
#   'reservation',
#   'we',
#   'had',
#   'their',
#   'beef',
#   'tartar',
#   'and',
#   'pork',
#   'belly',
#   'to',
#   'start',
#   'and',
#   'a',
#   'salmon',
#   'dish',
#   'and',
#   'lamb',
#   'meal',
#   'for',
#   'mains',
#   'everything',
#   'was',
#   'incredible',
#   'i',
#   'could',
#   'go',
#   'on',
#   'at',
#   'length',
#   'about',
#   'how',
#   'all',
#   'the',
#   'listed',
#   'ingredients',
#   'really',
#   'make',
#   'their',
#   'dishes',
#   'amazing',
#   'but',
#   'honestly',
#   'you',
#   'just',
#   'need',
#   'to',
#   'go',
#   'a',
#   'bit',
#   'outside',
#   'of',
#   'downtown',
#   'montreal',
#   'but',
#   'take',
#   'the',
#   'metro',
#   'out',
#   'and',
#   'its',
#   'less',
#   'than',
#   'a',
#   '10',
#   'minute',
#   'walk',
#   'from',
#   'the',
#   'station'],
#  ['lesters',
#   'is',
#   'located',
#   'in',
#   'a',
#   'beautiful',
#   'neighborhood',
#   'and',
#   'has',
#   'been',
#   'there',
#   'since',
#   '1951',
#   'they',
#   'are',
#   'known',
#   'for',
#   'smoked',
#   'meat',
#   'which',
#   'most',
#   'delis',
#   'have',
#   'but',
#   'their',
#   'brisket',
#   'sandwich',
#   'is',
#   'what',
#   'i',
#   'come',
#   'to',
#   'montreal',
#   'for',
#   'theyve',
#   'got',
#   'about',
#   '12',
#   'seats',
#   'outside',
#   'to',
#   'go',
#   'along',
#   'with',
#   'the',
#   'inside',
#   'the',
#   'smoked',
#   'meat',
#   'is',
#   'up',
#   'there',
#   'in',
#   'quality',
#   'and',
#   'taste',
#   'with',
#   'schwartzs',
#   'and',
#   'youll',
#   'find',
#   'less',
#   'tourists',
#   'at',
#   'lesters',
#   'as',
#   'well'],
#  ['love',
#   'coming',
#   'here',
#   'yes',
#   'the',
#   'place',
#   'always',
#   'needs',
#   'the',
#   'floor',
#   'swept',
#   'but',
#   'when',
#   'you',
#   'give',
#   'out',
#   'peanuts',
#   'in',
#   'the',
#   'shell',
#   'how',
#   'wont',
#   'it',
#   'always',
#   'be',
#   'a',
#   'bit',
#   'dirty',
#   'the',
#   'food',
#   'speaks',
#   'for',
#   'itself',
#   'so',
#   'good',
#   'burgers',
#   'are',
#   'made',
#   'to',
#   'order',
#   'and',
#   'the',
#   'meat',
#   'is',
#   'put',
#   'on',
#   'the',
#   'grill',
#   'when',
#   'you',
#   'order',
#   'your',
#   'sandwich',
#   'getting',
#   'the',
#   'small',
#   'burger',
#   'just',
#   'means',
#   '1',
#   'patty',
#   'the',
#   'regular',
#   'is',
#   'a',
#   '2',
#   'patty',
#   'burger',
#   'which',
#   'is',
#   'twice',
#   'the',
#   'deliciousness',
#   'getting',
#   'the',
#   'cajun',
#   'fries',
#   'adds',
#   'a',
#   'bit',
#   'of',
#   'spice',
#   'to',
#   'them',
#   'and',
#   'whatever',
#   'size',
#   'you',
#   'order',
#   'they',
#   'always',
#   'throw',
#   'more',
#   'fries',
#   'a',
#   'lot',
#   'more',
#   'fries',
#   'into',
#   'the',
#   'bag'],
#  ['had',
#   'their',
#   'chocolate',
#   'almond',
#   'croissant',
#   'and',
#   'it',
#   'was',
#   'amazing',
#   'so',
#   'light',
#   'and',
#   'buttery',
#   'and',
#   'oh',
#   'my',
#   'how',
#   'chocolaty',
#   'if',
#   'youre',
#   'looking',
#   'for',
#   'a',
#   'light',
#   'breakfast',
#   'then',
#   'head',
#   'out',
#   'here',
#   'perfect',
#   'spot',
#   'for',
#   'a',
#   'coffeelatté',
#   'before',
#   'heading',
#   'out',
#   'to',
#   'the',
#   'old',
#   'port'],
#  ['cycle',
#   'pub',
#   'las',
#   'vegas',
#   'was',
#   'a',
#   'blast',
#   'got',
#   'a',
#   'groupon',
#   'and',
#   'rented',
#   'the',
#   'bike',
#   'for',
#   '11',
#   'of',
#   'us',
#   'for',
#   'an',
#   'afternoon',
#   'tour',
#   'each',
#   'bar',
#   'was',
#   'more',
#   'fun',
#   'than',
#   'the',
#   'last',
#   'downtown',
#   'las',
#   'vegas',
#   'has',
#   'changed',
#   'so',
#   'much',
#   'and',
#   'for',
#   'the',
#   'better',
#   'we',
#   'had',
#   'a',
#   'wide',
#   'age',
#   'range',
#   'in',
#   'this',
#   'group',
#   'from',
#   'early',
#   '20s',
#   'to',
#   'mid',
#   '50s',
#   'and',
#   'everyone',
#   'had',
#   'so',
#   'much',
#   'fun',
#   'our',
#   'driver',
#   'tony',
#   'was',
#   'knowledgable',
#   'friendly',
#   'and',
#   'just',
#   'plain',
#   'fun',
#   'would',
#   'recommend',
#   'this',
#   'to',
#   'anyone',
#   'looking',
#   'to',
#   'do',
#   'something',
#   'different',
#   'away',
#   'from',
#   'the',
#   'strip',
#   'you',
#   'wont',
#   'be',
#   'disappointed'],
#  ['who',
#   'would',
#   'have',
#   'guess',
#   'that',
#   'you',
#   'would',
#   'be',
#   'able',
#   'to',
#   'get',
#   'fairly',
#   'decent',
#   'vietnamese',
#   'restaurant',
#   'in',
#   'east',
#   'york',
#   'not',
#   'quite',
#   'the',
#   'same',
#   'as',
#   'chinatown',
#   'in',
#   'terms',
#   'of',
#   'pricing',
#   'slightly',
#   'higher',
#   'but',
#   'definitely',
#   'one',
#   'of',
#   'the',
#   'better',
#   'vietnamese',
#   'restaurants',
#   'outside',
#   'of',
#   'the',
#   'neighbourhood',
#   'when',
#   'i',
#   'dont',
#   'have',
#   'time',
#   'to',
#   'go',
#   'to',
#   'chinatown',
#   'this',
#   'is',
#   'the',
#   'next',
#   'best',
#   'thing',
#   'as',
#   'it',
#   'is',
#   'down',
#   'the',
#   'street',
#   'from',
#   'me',
#   'so',
#   'far',
#   'the',
#   'only',
#   'items',
#   'i',
#   'have',
#   'tried',
#   'are',
#   'the',
#   'phos',
#   'beef',
#   'chicken',
#   'vegetarian',
#   'and',
#   'they',
#   'have',
#   'not',
#   'disappointed',
#   'me',
#   'especially',
#   'the',
#   'chicken',
#   'pho',
#   'next',
#   'time',
#   'i',
#   'go',
#   'back',
#   'im',
#   'going',
#   'to',
#   'try',
#   'the',
#   'banh',
#   'cuon',
#   'steamed',
#   'rice',
#   'noodle',
#   'and',
#   'the',
#   'vermicelli'],
#  ['always',
#   'drove',
#   'past',
#   'this',
#   'coffee',
#   'house',
#   'and',
#   'wondered',
#   'about',
#   'it',
#   'bf',
#   'and',
#   'i',
#   'finally',
#   'made',
#   'the',
#   'stop',
#   'to',
#   'try',
#   'this',
#   'place',
#   'out',
#   'cute',
#   'quaint',
#   'coffee',
#   'shop',
#   'with',
#   'nice',
#   'muskoka',
#   'chairs',
#   'outside',
#   'bf',
#   'ordered',
#   'an',
#   'ice',
#   'coffee',
#   'and',
#   'really',
#   'enjoyed',
#   'it',
#   'guess',
#   'we',
#   'will',
#   'be',
#   'back',
#   'again'],
#  ['not',
#   'bad',
#   'love',
#   'that',
#   'there',
#   'is',
#   'a',
#   'glutenfree',
#   'vegan',
#   'version',
#   'of',
#   'the',
#   'cheese',
#   'curds',
#   'and',
#   'gravy',
#   'havent',
#   'done',
#   'the',
#   'poutine',
#   'taste',
#   'test',
#   'yet',
#   'with',
#   'smokes',
#   'but',
#   'im',
#   'excited',
#   'to',
#   'see',
#   'which',
#   'is',
#   'better',
#   'however',
#   'poutinis',
#   'might',
#   'win',
#   'as',
#   'they',
#   'are',
#   'vegan',
#   'and',
#   'glutenfree'],
#  ['love',
#   'this',
#   'place',
#   'peggy',
#   'is',
#   'great',
#   'with',
#   'dogs',
#   'and',
#   'does',
#   'a',
#   'great',
#   'job',
#   'she',
#   'is',
#   'very',
#   'patience',
#   'with',
#   'him',
#   'and',
#   'will',
#   'make',
#   'any',
#   'adjustments',
#   'you',
#   'need',
#   'before',
#   'you',
#   'leave',
#   'the',
#   'store',
#   'my',
#   'little',
#   'guy',
#   'has',
#   'no',
#   'problems',
#   'coming',
#   'here',
#   'they',
#   'also',
#   'have',
#   'very',
#   'good',
#   'bully',
#   'sticks',
#   'the',
#   'nonsmelly',
#   'ones',
#   'that',
#   'my',
#   'little',
#   'guy',
#   'and',
#   'his',
#   'friends',
#   'love']]

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
#defining the function to remove stopwords
stopwords = nltk.corpus.stopwords.words('english')
def remove_stopwords(text):
    output= [i for i in text if i not in stopwords]
    return output
#applying function to the column
cleaned_reviews = []
for i in tokenized_reviews:
    cleaned_reviews.append(remove_stopwords(i))
cleaned_reviews[:10]
# Out:
# [nltk_data] Downloading package punkt to /Users/weichi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/weichi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 15
#      13 #applying function to the column
#      14 cleaned_reviews = []
# ---> 15 for i in tokenized_reviews:
#      16     cleaned_reviews.append(remove_stopwords(i))
#      17 cleaned_reviews[:10]
#
# NameError: name 'tokenized_reviews' is not defined

# %%
from nltk.stem import WordNetLemmatizer
#defining the object for Lemmatization
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import wordnet
from nltk.corpus import wordnet as wn

wordnet_lemmatizer = WordNetLemmatizer()

#defining the function for lemmatization
def lemmatizer(text):
    lemm_text = [wordnet_lemmatizer.lemmatize(word) for word in text]
    return lemm_text
#applying function to the column
lemmatized_reviews = []
for i in cleaned_reviews:
    lemmatized_reviews.append(lemmatizer(i))
lemmatized_reviews[:10]
# Out:
# [nltk_data] Downloading package wordnet to /Users/weichi/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /Users/weichi/nltk_data...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/weichi/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [['super',
#   'simple',
#   'place',
#   'amazing',
#   'nonetheless',
#   'around',
#   'since',
#   '30',
#   'still',
#   'serve',
#   'thing',
#   'started',
#   'bologna',
#   'salami',
#   'sandwich',
#   'mustard',
#   'staff',
#   'helpful',
#   'friendly'],
#  ['small',
#   'unassuming',
#   'place',
#   'change',
#   'menu',
#   'every',
#   'often',
#   'cool',
#   'decor',
#   'vibe',
#   'inside',
#   '30',
#   'seat',
#   'restaurant',
#   'call',
#   'reservation',
#   'beef',
#   'tartar',
#   'pork',
#   'belly',
#   'start',
#   'salmon',
#   'dish',
#   'lamb',
#   'meal',
#   'main',
#   'everything',
#   'incredible',
#   'could',
#   'go',
#   'length',
#   'listed',
#   'ingredient',
#   'really',
#   'make',
#   'dish',
#   'amazing',
#   'honestly',
#   'need',
#   'go',
#   'bit',
#   'outside',
#   'downtown',
#   'montreal',
#   'take',
#   'metro',
#   'le',
#   '10',
#   'minute',
#   'walk',
#   'station'],
#  ['lesters',
#   'located',
#   'beautiful',
#   'neighborhood',
#   'since',
#   '1951',
#   'known',
#   'smoked',
#   'meat',
#   'deli',
#   'brisket',
#   'sandwich',
#   'come',
#   'montreal',
#   'theyve',
#   'got',
#   '12',
#   'seat',
#   'outside',
#   'go',
#   'along',
#   'inside',
#   'smoked',
#   'meat',
#   'quality',
#   'taste',
#   'schwartzs',
#   'youll',
#   'find',
#   'le',
#   'tourist',
#   'lesters',
#   'well'],
#  ['love',
#   'coming',
#   'yes',
#   'place',
#   'always',
#   'need',
#   'floor',
#   'swept',
#   'give',
#   'peanut',
#   'shell',
#   'wont',
#   'always',
#   'bit',
#   'dirty',
#   'food',
#   'speaks',
#   'good',
#   'burger',
#   'made',
#   'order',
#   'meat',
#   'put',
#   'grill',
#   'order',
#   'sandwich',
#   'getting',
#   'small',
#   'burger',
#   'mean',
#   '1',
#   'patty',
#   'regular',
#   '2',
#   'patty',
#   'burger',
#   'twice',
#   'deliciousness',
#   'getting',
#   'cajun',
#   'fry',
#   'add',
#   'bit',
#   'spice',
#   'whatever',
#   'size',
#   'order',
#   'always',
#   'throw',
#   'fry',
#   'lot',
#   'fry',
#   'bag'],
#  ['chocolate',
#   'almond',
#   'croissant',
#   'amazing',
#   'light',
#   'buttery',
#   'oh',
#   'chocolaty',
#   'youre',
#   'looking',
#   'light',
#   'breakfast',
#   'head',
#   'perfect',
#   'spot',
#   'coffeelatté',
#   'heading',
#   'old',
#   'port'],
#  ['cycle',
#   'pub',
#   'la',
#   'vega',
#   'blast',
#   'got',
#   'groupon',
#   'rented',
#   'bike',
#   '11',
#   'u',
#   'afternoon',
#   'tour',
#   'bar',
#   'fun',
#   'last',
#   'downtown',
#   'la',
#   'vega',
#   'changed',
#   'much',
#   'better',
#   'wide',
#   'age',
#   'range',
#   'group',
#   'early',
#   '20',
#   'mid',
#   '50',
#   'everyone',
#   'much',
#   'fun',
#   'driver',
#   'tony',
#   'knowledgable',
#   'friendly',
#   'plain',
#   'fun',
#   'would',
#   'recommend',
#   'anyone',
#   'looking',
#   'something',
#   'different',
#   'away',
#   'strip',
#   'wont',
#   'disappointed'],
#  ['would',
#   'guess',
#   'would',
#   'able',
#   'get',
#   'fairly',
#   'decent',
#   'vietnamese',
#   'restaurant',
#   'east',
#   'york',
#   'quite',
#   'chinatown',
#   'term',
#   'pricing',
#   'slightly',
#   'higher',
#   'definitely',
#   'one',
#   'better',
#   'vietnamese',
#   'restaurant',
#   'outside',
#   'neighbourhood',
#   'dont',
#   'time',
#   'go',
#   'chinatown',
#   'next',
#   'best',
#   'thing',
#   'street',
#   'far',
#   'item',
#   'tried',
#   'phos',
#   'beef',
#   'chicken',
#   'vegetarian',
#   'disappointed',
#   'especially',
#   'chicken',
#   'pho',
#   'next',
#   'time',
#   'go',
#   'back',
#   'im',
#   'going',
#   'try',
#   'banh',
#   'cuon',
#   'steamed',
#   'rice',
#   'noodle',
#   'vermicelli'],
#  ['always',
#   'drove',
#   'past',
#   'coffee',
#   'house',
#   'wondered',
#   'bf',
#   'finally',
#   'made',
#   'stop',
#   'try',
#   'place',
#   'cute',
#   'quaint',
#   'coffee',
#   'shop',
#   'nice',
#   'muskoka',
#   'chair',
#   'outside',
#   'bf',
#   'ordered',
#   'ice',
#   'coffee',
#   'really',
#   'enjoyed',
#   'guess',
#   'back'],
#  ['bad',
#   'love',
#   'glutenfree',
#   'vegan',
#   'version',
#   'cheese',
#   'curd',
#   'gravy',
#   'havent',
#   'done',
#   'poutine',
#   'taste',
#   'test',
#   'yet',
#   'smoke',
#   'im',
#   'excited',
#   'see',
#   'better',
#   'however',
#   'poutinis',
#   'might',
#   'win',
#   'vegan',
#   'glutenfree'],
#  ['love',
#   'place',
#   'peggy',
#   'great',
#   'dog',
#   'great',
#   'job',
#   'patience',
#   'make',
#   'adjustment',
#   'need',
#   'leave',
#   'store',
#   'little',
#   'guy',
#   'problem',
#   'coming',
#   'also',
#   'good',
#   'bully',
#   'stick',
#   'nonsmelly',
#   'one',
#   'little',
#   'guy',
#   'friend',
#   'love']]

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import matplotlib.pyplot as plt
nltk.download('vader_lexicon')

vader = SentimentIntensityAnalyzer()
import matplotlib.pyplot as plt
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk

vader = SentimentIntensityAnalyzer()

compound_scores = []
negative_scores = []
positive_scores = []
neutral_scores = []

# Assuming `lower[:20]` is a list of preprocessed strings
for text in lower[:4000]:
    score = vader.polarity_scores(text)
    compound_scores.append(score['compound'])
    if score['compound'] >= 0.99:
        print(text)

# Plot compound score histogram
plt.figure(figsize=(8, 5))
plt.hist(compound_scores, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
plt.title('Histogram of VADER Compound Sentiment Scores')
plt.xlabel('Compound Sentiment Score')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/weichi/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# alice jane and the entire staff here stand out above the rest of the nail salons in town  believe me ive tried a vast majority of them
# ive now been going here for well over a year  i refer anyone and everyone i know here as well as bringing friends who are in town here  my mom and myself are regulars and we wouldnt have it any other way
# always a lovely experience a relaxed ambiance and movies  yes new and current movies as well as some classics
# absolutely everything about stars nails is comfortable the mani stations the pedi chairs and yes all are facing the tv set for perfect movie viewing
# classic mani and pediatric they have them  trendy pedi treatments and facials have them as well  colors of the trendy shades abound
# rejoice  its here for you along with reasonable pricing and excellent service
# dont be ashamed how bad joss feet become boot season is here and those crest feet in wed of a wonderful pedi treatment  star nails has a pedi menu peruse it and be inclined to try all  beauty intervention here is a pleasure tuning those feet and legs  trust me feet deserve this place they do support the entire body think about it why would anyone in their right mind not treat them well
# jane alice or any of the staff here will sooth moisturize with a dose of sloughing lotion and buff to perfection ahh what a relief right
# the finale will be a slight massage for those hands or feet and then polish viola
# i started coming here the day they opened their doors for the first time and im so glad the place is super clean and organized they have a light but nice vintage touch on their decoration and everybody is just very friendly its the only nail place ive been to that i actually met the owner and see her regularly greeting costumers and making conversation with them it just makes it for a more inviting place
    polarity_scores.append(blob.sentiment.polarity)

# Bar plot of polarity scores (binned)
import numpy as np
bins = np.linspace(-1, 1, 21)
hist, bin_edges = np.histogram(polarity_scores, bins=bins)
bin_centers = 0.5 * (bin_edges[1:] + bin_edges[:-1])

plt.figure(figsize=(10, 6))
plt.bar(bin_centers, hist, width=0.09, color='lightcoral', edgecolor='black')
plt.title('Bar Plot of TextBlob Polarity Scores')
plt.xlabel('Polarity Score (Binned)')
plt.ylabel('Frequency')
plt.grid(True, axis='y')
plt.show()

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")
texts = lower[:2000] 
results = classifier(texts, truncation=True, batch_size=16)
positive = []
negative = []
for text, res in zip(texts, results):
    if res['label'] == 'POSITIVE':
        positive.append(text)
    else:
        negative.append(text)
# Out:
# Device set to use mps:0

# %%
import wordcloud
from wordcloud import WordCloud
from bertopic import BERTopic
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)  
    words = text.split()
    words = [w for w in words if w not in stop_words]
    return ' '.join(words)
lower_cleaned = [clean_text(review) for review in positive]
lower_cleaned2 = [clean_text(review) for review in negative]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/weichi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
from umap import UMAP
def simple_adjective_extraction(text):
    words = re.findall(r'\b\w+\b', text.lower())
    adj_like = [w for w in words if w.endswith(('ful', 'ous', 'ive', 'less', 'able', 'al', 'ic', 'y', 'ing', 'ed', 'acrylic'))]
    return ' '.join(adj_like)

lower_adj = [simple_adjective_extraction(review) for review in lower_cleaned]

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(lower_adj)
topic_info = topic_model.get_topic_info()


lower_adj2 = [simple_adjective_extraction(review) for review in lower_cleaned2]
print(lower_adj2)



umap_model = UMAP(random_state=9)  # fixed seed for reproducibility
topic_model2 = BERTopic(umap_model=umap_model)

topics2, probs2 = topic_model2.fit_transform(lower_adj)
topic_info2 = topic_model2.get_topic_info()
print(topic_info2)

dict1 = {
    'amazing': 500,
    'definitely coming': 121,
    'friendly': 121,
    'professional': 56,
    'affordable': 41,
    'relaxing': 35,
    'beautiful': 21,
    'exceptional': 17,
    'wonderful staying': 15,
    'sanitized': 15,
    'cleaned': 15,
    'luxury':13,
    'accomodating': 12,  
}
# Out:
# ['ive tried majority ive going bringing way lovely relaxed absolutely everything comfortable facing viewing classic pediatric trendy trendy reasonable pricing ashamed wed wonderful inclined try beauty tuning body sloughing', 'birthday excited every recently moved looking anyway reading excited arrived busy running offered walked birthday day arrived rushed offered clearly lady enjoy getting disappointed receive needless say happy birthday coming', 'careful give wanted usually expected going', 'saying ive say fancy ive tried going', 'filed removing polishing dirty unmanicured manicureshed manicured', 'lady birthday nothing building finally meaning going thinking talking looking play respectfully need stopped finally lady ugly started terrorized amazing usually reading disturbing ive', 'disappointed today awful beautiful friendly', 'wanted lengthy wanted asymetrical showed wanted looked assumed exactly wanted genuinely usually parted titled asymetrical parted lengthy previously exactly wanted anyway pissed everyday dealing reminded', 'money wanted asked informed repeatedly telling give saying basic day already chipping already falling nothing rubbing literally money money', 'called asked ricky really cared used rushed ruined every asked natural looking finally', 'treated painted dry repainted going bloody pinky apology clearly bleeding attentive way booked satisfied paying money seemed', 'today anniversary knicked assumed asked continued started wondered wiped every stinging started bleed tried continued bleed proceeded getting progressively frustrated hoped many apply turned noticed showing tried apology appalled unprofessional looked coming frustrating wearing every', 'ive going quality acrylic used rarely holly definitely pay', 'probably homeboy vaping ive less energy expanding', 'mixed decided try anyway needless say unfortunately getting danny okay personable relaxing normally painting trying telling saying need candy say candy painted telling going going painted wanted actual thing try going denny', 'removed walked red reeked used scrubbing removing clay used thoroughly clay polishing used repeatedly scratched dried stay dirty looked applied looked bumpy dried way dry coming highly stay away', 'filled completely freezing asked okay turned turned rushed finished started wanted wanted rushed apologized wanted dry charged apology charged charged', 'moved away coming waxing really liked located busy trafficy parking parking really really provided waxing emily spelling really every chatted noticed waxing table ratty entirely probably replaced may helpful personal electronic potentially sensitive anyway anybody going', 'looking lacking walked started filling added started asked desired minimal thing asked pay', 'finally going constantly trying bleed kinglady reasonably priced asking liked fancy every', 'glued individual causing natural painful extremely painful getting removed', 'today watched used rinsed happy nothing happening disappointed', 'moved difficulty finding way amazing reached opened immediately received booked confirmed opened arrival greeted friendly soaking everything professional complimentary definitely chipped cracked easy definitely disappointed quality chipped deal frustrating lasting', 'usually today lady greeting anything welcoming telling wanted informed explained way steady continued try blatantly friendly anything okay abruptly thing lady wanted okay probably ive living', 'asked rounded removed', 'learned addicted filing cleaning loving', 'thing say awful speakingjoking acrylic retired traveling several mostly chipped day chipped ring pealed fixing', 'walking immediately rushed started arrived lady extremely charged money completely asked talking', 'lady pulling shaped birthday thing', 'waited busy going lazy trying thinking total money', 'disappointed seemed noticed going pay unprofessional table continued definitely walked money wasted', 'peeled chipped okay fixed started personality inexperienced', 'r ...
#    Topic  Count                               Name  \
# 0     -1     21   -1_able_chipped_cindy_everything
# 1      0   1310  0_amazing_friendly_ive_definitely
# 2      1     18                 1_correcting_say__
# 3      2     11         2_tony_guy_friendly_really
#
#                                       Representation  \
# 0  [able, chipped, cindy, everything, really, tur...
# 1  [amazing, friendly, ive, definitely, really, h...
# 2                  [correcting, say, , , , , , , , ]
# 3  [tony, guy, friendly, really, professional, ev...
#
#                                  Representative_Docs
# 0  [visited referred updated able quickly chippin...
# 1  [amazing every ive quality highly, local recei...
# 2                                [, say, correcting]
# 3  [tony friendly happy positive energy knowledge...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt



# Your dictionary
dict1 = {
    'amazing': 500,
    'definitely coming': 121,
    'friendly': 121,
    'professional': 56,
    'affordable': 41,
    'relaxing': 35,
    'beautiful': 21,
    'exceptional': 17,
    'wonderful staying': 15,
    'sanitized': 15,
    'cleaned': 15,
    'luxury': 13,
    'accomodating': 12
}
dict2 = {
    'waiting': 47,
    'busy':47,
    'overpriced': 32,
    'peeling_chipped': 31,
    'dirty':27,
    'scrubbed':27,
    'callous': 27,
    'bleeding':20,
    'sloppy': 20,
    'crooked':17,
    'denying':13
}

# Create the WordCloud
wordcloud1 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict1)

# Plot it
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Positive Words from Reviews')

plt.show()
wordcloud2 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict2)
# Plot it
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis('off')
plt.title('Negative Words from Reviews')
plt.show()
